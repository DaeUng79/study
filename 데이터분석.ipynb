# %%
#필요한 라이브러리를 임포트하고 샘플 데이터를 생성합니다.

import pandas as pd
import matplotlib.pyplot as plt

# 샘플 데이터 생성
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [23, 35, 45, 28, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'Salary': [70000, 80000, 120000, 75000, 95000]
}

df = pd.DataFrame(data)
display(df)
# Out:
#       Name  Age         City  Salary
# 0    Alice   23     New York   70000
# 1      Bob   35  Los Angeles   80000
# 2  Charlie   45      Chicago  120000
# 3    David   28      Houston   75000
# 4      Eva   40      Phoenix   95000

# %%
# 평균 연령과 평균 급여를 계산합니다.
average_age = df['Age'].mean()
average_salary = df['Salary'].mean()

print(f"Average Age: {average_age:.2f}")
print(f"Average Salary: ${average_salary:.2f}")
# Out:
# Average Age: 34.20
# Average Salary: $88000.00

# %%
# 급여의 막대 그래프
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Salary'], color='skyblue')
plt.title('Salary of Employees')
plt.xlabel('Name')
plt.ylabel('Salary')
plt.show()

# %%
# 도시별 평균 급여
city_salary = df.groupby('City')['Salary'].mean()

plt.figure(figsize=(10, 6))
city_salary.plot(kind='bar', color='coral')
plt.title('Average Salary by City')
plt.xlabel('City')
plt.ylabel('Average Salary')
plt.show()
